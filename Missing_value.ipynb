# %%
import os  # For setting the working directory
import numpy as np   # For numpy calculations
import matplotlib.pyplot as plt   # For data visualization
import pandas as pd   # For DataFrame processing
import statsmodels.api as sm  # For getting the statistics of the final model
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
os.chdir('D:/MLP_Session_26_JULY/DATASET')
data = pd.read_csv('Lin_Reg_Sales_data.csv')

# %%
data.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          Low Fat         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.000000  Fruits and Vegetables
# 4         8.93          Low Fat         0.000000              Household
#
#    Item_MRP Outlet_Identifier  Yrs_since_inception Outlet_Size  \
# 0  249.8092            OUT049                   17      Medium
# 1   48.2692            OUT018                    7      Medium
# 2  141.6180            OUT049                   17      Medium
# 3  182.0950            OUT010                   18      Medium
# 4   53.8614            OUT013                   29        High
#
#   Outlet_Location_Type        Outlet_Type      sales
# 0               Tier 1  Supermarket Type1  3735.1380
# ...

# %%
data.shape
# Out:
# (7071, 11)

# %%
# Dropping the rows containing missing values

data.isnull().sum()
# Out:
# Item_Weight             11
# Item_Fat_Content         0
# Item_Visibility          0
# Item_Type                0
# Item_MRP                 0
# Outlet_Identifier        0
# Yrs_since_inception      0
# Outlet_Size              0
# Outlet_Location_Type     0
# Outlet_Type              0
# sales                    0
# dtype: int64

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# Item_Weight             0
# Item_Fat_Content        0
# Item_Visibility         0
# Item_Type               0
# Item_MRP                0
# Outlet_Identifier       0
# Yrs_since_inception     0
# Outlet_Size             0
# Outlet_Location_Type    0
# Outlet_Type             0
# sales                   0
# dtype: int64

# %%
data.shape
# Out:
# (7060, 11)

# %%
data = pd.read_csv('Lin_Reg_Sales_data.csv')

# %%
data.isnull().sum()
# Out:
# Item_Weight             11
# Item_Fat_Content         0
# Item_Visibility          0
# Item_Type                0
# Item_MRP                 0
# Outlet_Identifier        0
# Yrs_since_inception      0
# Outlet_Size              0
# Outlet_Location_Type     0
# Outlet_Type              0
# sales                    0
# dtype: int64

# %%
# Dropping the columns containing missing values

# Using labels

data = pd.read_csv('Lin_Reg_Sales_data.csv')

# %%
data1 = data.drop(['Item_Weight'],axis=1)

# %%
data1.head()
# Out:
#   Item_Fat_Content  Item_Visibility              Item_Type  Item_MRP  \
# 0          Low Fat         0.016047                  Dairy  249.8092
# 1          Regular         0.019278            Soft Drinks   48.2692
# 2          Low Fat         0.016760                   Meat  141.6180
# 3          Regular         0.000000  Fruits and Vegetables  182.0950
# 4          Low Fat         0.000000              Household   53.8614
#
#   Outlet_Identifier  Yrs_since_inception Outlet_Size Outlet_Location_Type  \
# 0            OUT049                   17      Medium               Tier 1
# 1            OUT018                    7      Medium               Tier 3
# 2            OUT049                   17      Medium               Tier 1
# 3            OUT010                   18      Medium               Tier 3
# 4            OUT013                   29        High               Tier 3
#
#          Outlet_Type      sales
# 0  Supermarket Type1  3735.1380
# 1  Supermarket Type2   443.4228
# ...

# %%
data1.shape
# Out:
# (7071, 10)

# %%
data.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          Low Fat         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.000000  Fruits and Vegetables
# 4         8.93          Low Fat         0.000000              Household
#
#    Item_MRP Outlet_Identifier  Yrs_since_inception Outlet_Size  \
# 0  249.8092            OUT049                   17      Medium
# 1   48.2692            OUT018                    7      Medium
# 2  141.6180            OUT049                   17      Medium
# 3  182.0950            OUT010                   18      Medium
# 4   53.8614            OUT013                   29        High
#
#   Outlet_Location_Type        Outlet_Type      sales
# 0               Tier 1  Supermarket Type1  3735.1380
# ...

# %%
data = pd.read_csv('Lin_Reg_Sales_data.csv')

# %%
data1 = data.drop(['Item_Weight'],axis=1, inplace=True)

# %%
data.head()
# Out:
#   Item_Fat_Content  Item_Visibility              Item_Type  Item_MRP  \
# 0          Low Fat         0.016047                  Dairy  249.8092
# 1          Regular         0.019278            Soft Drinks   48.2692
# 2          Low Fat         0.016760                   Meat  141.6180
# 3          Regular         0.000000  Fruits and Vegetables  182.0950
# 4          Low Fat         0.000000              Household   53.8614
#
#   Outlet_Identifier  Yrs_since_inception Outlet_Size Outlet_Location_Type  \
# 0            OUT049                   17      Medium               Tier 1
# 1            OUT018                    7      Medium               Tier 3
# 2            OUT049                   17      Medium               Tier 1
# 3            OUT010                   18      Medium               Tier 3
# 4            OUT013                   29        High               Tier 3
#
#          Outlet_Type      sales
# 0  Supermarket Type1  3735.1380
# 1  Supermarket Type2   443.4228
# ...

# %%
data1

# %%
data1.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-ad5d39181603> in <module>
# ----> 1 data1.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
# Dropping the columns containing missing values

# Using index position

data = pd.read_csv('Lin_Reg_Sales_data.csv')

# %%
data1 = data.drop(data.columns[[0]],axis=1)

# %%
data.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          Low Fat         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.000000  Fruits and Vegetables
# 4         8.93          Low Fat         0.000000              Household
#
#    Item_MRP Outlet_Identifier  Yrs_since_inception Outlet_Size  \
# 0  249.8092            OUT049                   17      Medium
# 1   48.2692            OUT018                    7      Medium
# 2  141.6180            OUT049                   17      Medium
# 3  182.0950            OUT010                   18      Medium
# 4   53.8614            OUT013                   29        High
#
#   Outlet_Location_Type        Outlet_Type      sales
# 0               Tier 1  Supermarket Type1  3735.1380
# ...

# %%
data1.head()
# Out:
#   Item_Fat_Content  Item_Visibility              Item_Type  Item_MRP  \
# 0          Low Fat         0.016047                  Dairy  249.8092
# 1          Regular         0.019278            Soft Drinks   48.2692
# 2          Low Fat         0.016760                   Meat  141.6180
# 3          Regular         0.000000  Fruits and Vegetables  182.0950
# 4          Low Fat         0.000000              Household   53.8614
#
#   Outlet_Identifier  Yrs_since_inception Outlet_Size Outlet_Location_Type  \
# 0            OUT049                   17      Medium               Tier 1
# 1            OUT018                    7      Medium               Tier 3
# 2            OUT049                   17      Medium               Tier 1
# 3            OUT010                   18      Medium               Tier 3
# 4            OUT013                   29        High               Tier 3
#
#          Outlet_Type      sales
# 0  Supermarket Type1  3735.1380
# 1  Supermarket Type2   443.4228
# ...

# %%
data = pd.read_csv('Lin_Reg_Sales_data.csv')

# %%
data1 = data.drop(data.columns[[0]],axis=1, inplace=True)

# %%
data.head()
# Out:
#   Item_Fat_Content  Item_Visibility              Item_Type  Item_MRP  \
# 0          Low Fat         0.016047                  Dairy  249.8092
# 1          Regular         0.019278            Soft Drinks   48.2692
# 2          Low Fat         0.016760                   Meat  141.6180
# 3          Regular         0.000000  Fruits and Vegetables  182.0950
# 4          Low Fat         0.000000              Household   53.8614
#
#   Outlet_Identifier  Yrs_since_inception Outlet_Size Outlet_Location_Type  \
# 0            OUT049                   17      Medium               Tier 1
# 1            OUT018                    7      Medium               Tier 3
# 2            OUT049                   17      Medium               Tier 1
# 3            OUT010                   18      Medium               Tier 3
# 4            OUT013                   29        High               Tier 3
#
#          Outlet_Type      sales
# 0  Supermarket Type1  3735.1380
# 1  Supermarket Type2   443.4228
# ...

# %%
data1.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-710ca0d3db0c> in <module>
# ----> 1 data1.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
data1

# %%
# Missing value imputation with mean

data = pd.read_csv('Lin_Reg_Sales_data.csv')

# %%
data.isnull().sum()
# Out:
# Item_Weight             11
# Item_Fat_Content         0
# Item_Visibility          0
# Item_Type                0
# Item_MRP                 0
# Outlet_Identifier        0
# Yrs_since_inception      0
# Outlet_Size              0
# Outlet_Location_Type     0
# Outlet_Type              0
# sales                    0
# dtype: int64

# %%
data['Item_Weight'].mean()
# Out:
# 12.857645184136183

# %%
data['Item_Weight'] = data['Item_Weight'].fillna(data['Item_Weight'].mean())

# %%
data['Item_Weight'].tail(20)
# Out:
# 7051    20.500000
# 7052    12.857645
# 7053    10.500000
# 7054    17.250000
# 7055     5.880000
# 7056    11.350000
# 7057     8.100000
# 7058    13.800000
# 7059    17.500000
# 7060    20.700000
# 7061    12.000000
# 7062    15.000000
# 7063    20.700000
# 7064    18.600000
# 7065    20.750000
# 7066     6.865000
# 7067     8.380000
# 7068    10.600000
# 7069     7.210000
# 7070    14.800000
# Name: Item_Weight, dtype: float64

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.chdir('D:/MLP_Session_26_JULY/DATASET')

# %%
data=pd.read_csv('Admission_Prediction.csv')

# %%
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1      337.0        118.0                4.0  4.5  4.5  9.65
# 1           2      324.0        107.0                4.0  4.0  4.5  8.87
# 2           3        NaN        104.0                3.0  3.0  3.5  8.00
# 3           4      322.0        110.0                3.0  3.5  2.5  8.67
# 4           5      314.0        103.0                2.0  2.0  3.0  8.21
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
data.corr()
# Out:
#                    Serial No.  GRE Score  TOEFL Score  University Rating  \
# Serial No.           1.000000  -0.098792    -0.140218          -0.050560
# GRE Score           -0.098792   1.000000     0.835273           0.638159
# TOEFL Score         -0.140218   0.835273     1.000000           0.655072
# University Rating   -0.050560   0.638159     0.655072           1.000000
# SOP                 -0.137352   0.616434     0.647666           0.723497
# LOR                 -0.003694   0.531996     0.541949           0.611437
# CGPA                -0.074289   0.829391     0.810473           0.706012
# Research            -0.005332   0.553755     0.469540           0.431253
# Chance of Admit      0.008505   0.810817     0.792369           0.690195
#
#                         SOP       LOR      CGPA  Research  Chance of Admit
# Serial No.        -0.137352 -0.003694 -0.074289 -0.005332         0.008505
# GRE Score          0.616434  0.531996  0.829391  0.553755         0.810817
# ...

# %%
sns.heatmap(data.corr(),cmap='viridis')
# Out:
# <AxesSubplot:>
